# %%
ls
# Out:
# sample_data/

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
# Out:
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/17/0f/04/b79c006972335e35472c0b835ed52bfc0815258d409f560108
# Successfully built gputil
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/69/86/6c/f8b8593bc273ec4b0c653d3827f7482bb2001a2781a73b7f44
# Successfully built humanize
# ...

# %%
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Gen RAM Free: 12.7 GB  | Proc size: 138.7 MB
# GPU RAM Free: 11439MB | Used: 0MB | Util   0% | Total 11439MB

# %%
# !git clone https://github.com/spMohanty/PlantVillage-Dataset.git
# Out:
# Cloning into 'PlantVillage-Dataset'...
# remote: Enumerating objects: 163229, done.
# remote: Total 163229 (delta 0), reused 0 (delta 0), pack-reused 163229
# Receiving objects: 100% (163229/163229), 2.00 GiB | 37.27 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# Checking out files: 100% (182401/182401), done.

# %%
# !ls
# Out:
# PlantVillage-Dataset  sample_data

# %%
cd PlantVillage-Dataset/
# Out:
# /content/PlantVillage-Dataset

# %%
ls
# Out:
# create_data_distribution.py        generate_mapstring.py
# create_db.py                       leaf_grouping/
# data_distribution_for_SVM/         leaf-map.json
# generate_data_color-20-80.sh*      raw/
# generate_data_color-40-60.sh*      README.md
# generate_data_color-50-50.sh*      run_all.sh*
# generate_data_color-60-40.sh*      slurm-476480.out
# generate_data_color-80-20.sh*      slurm-476481.out
# generate_data_for_SVM.py           slurm-476482.out
# generate_data_grayscale-20-80.sh*  slurm-476483.out
# generate_data_grayscale-40-60.sh*  slurm-476484.out
# generate_data_grayscale-50-50.sh*  slurm-476485.out
# generate_data_grayscale-60-40.sh*  slurm-476486.out
# generate_data_grayscale-80-20.sh*  slurm-476487.out
# generate_data_segmented-20-80.sh*  slurm-476488.out
# generate_data_segmented-40-60.sh*  slurm-476489.out
# generate_data_segmented-50-50.sh*  slurm-476490.out
# generate_data_segmented-60-40.sh*  slurm-476491.out
# ...

# %%
cd raw/
# Out:
# /content/PlantVillage-Dataset/raw

# %%
ls
# Out:
# color/  grayscale/  segmented/

# %%
cd segmented/
# Out:
# /content/PlantVillage-Dataset/raw/segmented

# %%
cd ..
# Out:
# /content/PlantVillage-Dataset/raw

# %%
mv segmented/ ../../

# %%
cd ../../
# Out:
# /content

# %%
ls
# Out:
# PlantVillage-Dataset/  sample_data/  segmented/

# %%
cd segmented/
# Out:
# /content/segmented

# %%
ls
# Out:
# Apple___Apple_scab/
# Apple___Black_rot/
# Apple___Cedar_apple_rust/
# Apple___healthy/
# Blueberry___healthy/
# Cherry_(including_sour)___healthy/
# Cherry_(including_sour)___Powdery_mildew/
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot/
# Corn_(maize)___Common_rust_/
# Corn_(maize)___healthy/
# Corn_(maize)___Northern_Leaf_Blight/
# Grape___Black_rot/
# Grape___Esca_(Black_Measles)/
# Grape___healthy/
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)/
# Orange___Haunglongbing_(Citrus_greening)/
# Peach___Bacterial_spot/
# Peach___healthy/
# Pepper,_bell___Bacterial_spot/
# Pepper,_bell___healthy/
# Potato___Early_blight/
# Potato___healthy/
# Potato___Late_blight/
# Raspberry___healthy/
# Soybean___healthy/
# Squash___Powdery_mildew/
# Strawberry___healthy/
# Strawberry___Leaf_scorch/
# Tomato___Bacterial_spot/
# Tomato___Early_blight/
# Tomato___healthy/
# Tomato___Late_blight/
# Tomato___Leaf_Mold/
# Tomato___Septoria_leaf_spot/
# Tomato___Spider_mites Two-spotted_spider_mite/
# ...

# %%
cd ..
# Out:
# /content

# %%
mkdir dataset

# %%
ls
# Out:
# dataset/  PlantVillage-Dataset/  sample_data/  segmented/

# %%
cp -r segmented/Tomato* dataset/

# %%
cd dataset/
# Out:
# /content/dataset

# %%
ls
# Out:
# Tomato___Bacterial_spot/  Tomato___Septoria_leaf_spot/
# Tomato___Early_blight/    Tomato___Spider_mites Two-spotted_spider_mite/
# Tomato___healthy/         Tomato___Target_Spot/
# Tomato___Late_blight/     Tomato___Tomato_mosaic_virus/
# Tomato___Leaf_Mold/       Tomato___Tomato_Yellow_Leaf_Curl_Virus/

# %%
mv "Tomato___Spider_mites Two-spotted_spider_mite" Tomato___Spider_mites_Two-spotted_spider_mite

# %%
ls
# Out:
# Tomato___Bacterial_spot/  Tomato___Septoria_leaf_spot/
# Tomato___Early_blight/    Tomato___Spider_mites_Two-spotted_spider_mite/
# Tomato___healthy/         Tomato___Target_Spot/
# Tomato___Late_blight/     Tomato___Tomato_mosaic_virus/
# Tomato___Leaf_Mold/       Tomato___Tomato_Yellow_Leaf_Curl_Virus/

# %%
import numpy as np
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt

import keras

from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.utils import to_categorical
from keras.optimizers import SGD, RMSprop, adadelta, Adam

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

from sklearn.model_selection import train_test_split

# %%
cd ..
# Out:
# /content

# %%
ls
# Out:
# dataset/  PlantVillage-Dataset/  sample_data/  segmented/

# %%
PATH = os.getcwd()
data_path = 'dataset'
data_Dir_list = os.listdir(data_path)
print(data_Dir_list)
img_row = 100
img_col = 100
num_channel = 3
epoch = 100
num_classes = 10
# Out:
# ['Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy', 'Tomato___Septoria_leaf_spot', 'Tomato___Bacterial_spot', 'Tomato___Spider_mites_Two-spotted_spider_mite', 'Tomato___Early_blight', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
img_data_list = []
images = []
i = 0

for dataset in data_Dir_list:
    img_list = os.listdir(data_path + '/' + dataset)
    for img in img_list:
        i = i + 1
        ip_img = cv2.imread(data_path + '/' + dataset + '/' + img)
        ip_img = cv2.resize(ip_img, (img_row, img_col))
        img_data_list.append(ip_img)
    images.append(i)

print(images)
# Out:
# [1909, 2861, 3234, 4825, 6596, 8723, 10399, 11399, 12803, 18160]

# %%
printm()
# Out:
# Gen RAM Free: 12.1 GB  | Proc size: 897.2 MB
# GPU RAM Free: 11439MB | Used: 0MB | Util   0% | Total 11439MB

# %%
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data /= 255
img_data.shape
# Out:
# (18160, 100, 100, 3)

# %%
# Preprocessing
n_samples = img_data.shape[0]
labels = np.ones((n_samples,), dtype='int64')

# %%
labels[:images[0]] = data_Dir_list.index(data_Dir_list[0])
label_dictionary = {}
label_dictionary[0] = data_Dir_list[0]

count = 0
for class_name in data_Dir_list:
    if count == 0:
        count += 1
        continue
    else:
        labels[images[count - 1]:images[count]
               ] = data_Dir_list.index(class_name)
        label_dictionary[count] = class_name
        count += 1

# %%
# One-Hot encoded format
Y = to_categorical(labels, num_classes)

# %%
print(label_dictionary)
# Out:
# {0: 'Tomato___Late_blight', 1: 'Tomato___Leaf_Mold', 2: 'Tomato___Tomato_mosaic_virus', 3: 'Tomato___healthy', 4: 'Tomato___Septoria_leaf_spot', 5: 'Tomato___Bacterial_spot', 6: 'Tomato___Spider_mites_Two-spotted_spider_mite', 7: 'Tomato___Early_blight', 8: 'Tomato___Target_Spot', 9: 'Tomato___Tomato_Yellow_Leaf_Curl_Virus'}

# %%
# Shuffle data
from sklearn.utils import shuffle
x, y = shuffle(img_data, Y, random_state=2)

# %%
printm()
# Out:
# Gen RAM Free: 7.7 GB  | Proc size: 5.8 GB
# GPU RAM Free: 11439MB | Used: 0MB | Util   0% | Total 11439MB

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.20, random_state=2)

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    shear_range=0.4,
    zoom_range=0.5,
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    # randomly rotate images in the range (degrees, 0 to 180)
    rotation_range=180,
    # randomly shift images horizontally (fraction of total width)
    width_shift_range=0.4,
    # randomly shift images vertically (fraction of total height)
    height_shift_range=0.4,
    horizontal_flip=True,  # randomly flip images
    vertical_flip=True)  # randomly flip images

# %%
datagen.fit(X_train)

# %%
tf.reset_default_graph()
model = Sequential()
model.add(Conv2D(32, (3, 3), strides=(1, 1),
                 activation='relu', input_shape=(img_row, img_col, num_channel)))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))
model.add(Conv2D(64, (3, 3), strides=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.5))
model.add(Conv2D(128, (3, 3), activation='relu'))
#model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(312, activation='relu'))
#model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 98, 98, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 47, 47, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 21, 21, 128)       73856
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 56448)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 312)               17612088
# ...

# %%
augmented_checkpoint = ModelCheckpoint('augmented_best_model.hdf5',  # model filename
                                       monitor='val_loss',  # quantity to monitor
                                       verbose=1,  # verbosity - 0 or 1
                                       save_best_only=True,  # The latest best model will not be overwritten
                                       mode='auto')  # The decision to overwrite model is made
# automatically depending on the quantity to monitor

# %%
model.compile(loss=keras.losses.categorical_crossentropy,  # Better loss function for neural networks
              optimizer=keras.optimizers.Adam(),  # Adam optimizer with 1.0e-4 learning rate
              metrics=['accuracy'])  # Metrics to be evaluated by the model

# %%
H = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=64),  # number of samples per gradient update
                           epochs=epoch,  # number of iterations
                           validation_data=(X_test, Y_test),
                           callbacks=[augmented_checkpoint],
                           verbose=1,
                           shuffle=True)
# Out:
# Epoch 1/100
# 227/227 [==============================] - 50s 222ms/step - loss: 1.6978 - acc: 0.4220 - val_loss: 1.1759 - val_acc: 0.5735
#
# Epoch 00001: val_loss improved from inf to 1.17593, saving model to augmented_best_model.hdf5
# Epoch 2/100
# 227/227 [==============================] - 48s 210ms/step - loss: 1.1728 - acc: 0.5968 - val_loss: 0.9506 - val_acc: 0.6605
#
# Epoch 00002: val_loss improved from 1.17593 to 0.95056, saving model to augmented_best_model.hdf5
# Epoch 3/100
# 227/227 [==============================] - 48s 210ms/step - loss: 0.9941 - acc: 0.6540 - val_loss: 0.9021 - val_acc: 0.6936
#
# Epoch 00003: val_loss improved from 0.95056 to 0.90214, saving model to augmented_best_model.hdf5
# Epoch 4/100
# 227/227 [==============================] - 48s 210ms/step - loss: 0.9238 - acc: 0.6788 - val_loss: 0.8339 - val_acc: 0.7150
#
# Epoch 00004: val_loss improved from 0.90214 to 0.83392, saving model to augmented_best_model.hdf5
# Epoch 5/100
# ...

# %%
mkdir model

# %%
model.save('./model/model.hdf5')

# %%
import pickle

with open('./model/history', 'wb') as file_pi:
    pickle.dump(H.history, file_pi)

# %%
cp dataset/Tomato___Late_blight/017a9839-6097-45aa-85b0-3051db151484___RS_Late.B\ 5125_final_masked.jpg sample.jpg

# %%
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
N = epoch
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")
plt.savefig("plant_monitor.png")

# %%
ls
# Out:
# augmented_best_model.hdf5  model/                 sample_data/  segmented/
# dataset/                   PlantVillage-Dataset/  sample.jpg

# %%
# import the necessary packages
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import numpy as np
import argparse
#import imutils
import pickle
import cv2
import os
import matplotlib.pyplot as plt


# image_path = "sample.jpg"
image_path = "Late-Blight-56a34bc55f9b58b7d0d15210.jpg"
# model_path = "plant_disease.model"
# binarizer_path = "plant_disease.pickle"

# load the image
image = cv2.imread(image_path)
output = image.copy()
 
# pre-process the image for classification
image = cv2.resize(image, (img_row, img_col))
image = image.astype("float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# load the trained convolutional neural network and the label
# binarizer
# print("[INFO] loading network...")
# model = load_model(model_path)
# lb = pickle.loads(open(binarizer_path, "rb").read())

# classify the input image
print("[INFO] classifying image...")
proba = model.predict(image)[0]
idx = np.argmax(proba)
# label = lb.classes_[idx]

cv2.putText(output, label_dictionary[idx], (10, 25),  cv2.FONT_HERSHEY_SIMPLEX,
	0.7, (0, 255, 0), 2)
cv2.putText(output, str(np.max(proba) * 100) + " %", (10, 55),  cv2.FONT_HERSHEY_SIMPLEX,
	0.7, (255, 0, 0), 2)


# show the output image
print("[INFO] class followed by probability...")
plt.imshow(output)
# Out:
# [INFO] classifying image...
# [INFO] class followed by probability...

# %%
# !wget "https://www.extension.umn.edu/garden/fruit-vegetable/plant-diseases/bacterial-spot-tomato-pepper/img/bacterial-specspot-leaf2-800.jpg"
# Out:
# Redirecting output to ‘wget-log.5’.

# %%
ls
# Out:
# augmented_best_model.hdf5                                sample.jpg
# clip_image002_186.jpg                                    segmented/
# dataset/                                                 wget-log
# early-blight-leaf-1.jpg                                  wget-log.1
# Late-Blight-56a34bc55f9b58b7d0d15210.jpg                 wget-log.2
# model/                                                   wget-log.3
# mosaic-pattern-tomato-leaf-tobacco-mosaic-virus-tmv.jpg  wget-log.4
# PlantVillage-Dataset/                                    wget-log.5
# sample_data/

# %%
printm()
# Out:
# Gen RAM Free: 5.2 GB  | Proc size: 9.0 GB
# GPU RAM Free: 11439MB | Used: 0MB | Util   0% | Total 11439MB

# %%
from google.colab import files
files.download('./model/model.hdf5')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 58514, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
# ...

# %%
files.download('./model/history')
files.download('plant_monitor.png')

# %%
# !pip install pyrebase
# Out:
# ...
#     100% |████████████████████████████████| 460kB 10.3MB/s
# ...
#     100% |████████████████████████████████| 522kB 12.2MB/s
# ...
#     100% |████████████████████████████████| 81kB 13.2MB/s
# ...
#     100% |████████████████████████████████| 6.5MB 915kB/s
# ...
#     100% |████████████████████████████████| 61kB 22.8MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/b9/04/ff/66c87c7e2419fd477f52015468ec5301d9480b6f3896babda4
# done
#   Stored in directory: /root/.cache/pip/wheels/48/f7/87/b932f09c6335dbcf45d916937105a372ab14f353a9ca431d7d
# done
#   Stored in directory: /root/.cache/pip/wheels/8f/9d/63/f6aea5612d1682a50b25857b0358e2ecec878a0bc42ba3af4c
# done
#   Stored in directory: /root/.cache/pip/wheels/42/66/97/11aed97607cb2379c1d35d02bdc159bcc3918eb0cc20f7eb9a
# Successfully built gcloud oauth2client pycryptodome jws
# spacy 2.0.12 has requirement requests<3.0.0,>=2.13.0, but you'll have requests 2.11.1 which is incompatible.
# ...

# %%
config = {
    'apiKey': "AIzaSyBwrK0N6Io6Q99diXZ9XjmTlVnN2kIyv28",
    'authDomain': "groovybucket-f731e.firebaseapp.com",
    'databaseURL': "https://groovybucket-f731e.firebaseio.com",
    'projectId': "groovybucket-f731e",
    'storageBucket': "groovybucket-f731e.appspot.com",
    'messagingSenderId': "255946216270"
}

# %%
import pyrebase

# %%
firebase = pyrebase.initialize_app(config)

# %%
storage = firebase.storage()

# %%
storage.child('model.hdf5').put('./model/model.hdf5')
# Out:
# {'bucket': 'groovybucket-f731e.appspot.com',
#  'contentDisposition': "inline; filename*=utf-8''model.hdf5",
#  'contentEncoding': 'identity',
#  'crc32c': 'Wm7Szw==',
#  'downloadTokens': '259dff69-0aec-4ce9-9556-d435e6ef0325',
#  'etag': 'CLHRnqLr4t0CEAE=',
#  'generation': '1538314281134257',
#  'md5Hash': '0N9AzRfkT1HAZsRqhSdJbA==',
#  'metageneration': '1',
#  'name': 'model.hdf5',
#  'size': '212542632',
#  'storageClass': 'STANDARD',
#  'timeCreated': '2018-09-30T13:31:21.133Z',
#  'updated': '2018-09-30T13:31:21.133Z'}

# %%
storage.child('augmented_best_model.hdf5').put('augmented_best_model.hdf5')
# Out:
# {'bucket': 'groovybucket-f731e.appspot.com',
#  'contentDisposition': "inline; filename*=utf-8''augmented_best_model.hdf5",
#  'contentEncoding': 'identity',
#  'crc32c': 'AicKfQ==',
#  'downloadTokens': '0232e665-629f-41ee-8c0f-90023bdb9088',
#  'etag': 'CJLbp97r4t0CEAE=',
#  'generation': '1538314407112082',
#  'md5Hash': 'MQlpVhGbBzDgIHE/0qN4xQ==',
#  'metageneration': '1',
#  'name': 'augmented_best_model.hdf5',
#  'size': '212542632',
#  'storageClass': 'STANDARD',
#  'timeCreated': '2018-09-30T13:33:27.111Z',
#  'updated': '2018-09-30T13:33:27.111Z'}

# %%
from keras.models import load_model
# Out:
# /home/praneet/envs/deeplearning/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = load_model('model.hdf5')

# %%
label_dictionary = {0: 'Tomato___Late_blight', 1: 'Tomato___Leaf_Mold', 2: 'Tomato___Tomato_mosaic_virus', 3: 'Tomato___healthy', 4: 'Tomato___Septoria_leaf_spot', 5: 'Tomato___Bacterial_spot', 6: 'Tomato___Spider_mites_Two-spotted_spider_mite', 7: 'Tomato___Early_blight', 8: 'Tomato___Target_Spot', 9: 'Tomato___Tomato_Yellow_Leaf_Curl_Virus'}

# %%
label_dictionary
# Out:
# {0: 'Tomato___Late_blight',
#  1: 'Tomato___Leaf_Mold',
#  2: 'Tomato___Tomato_mosaic_virus',
#  3: 'Tomato___healthy',
#  4: 'Tomato___Septoria_leaf_spot',
#  5: 'Tomato___Bacterial_spot',
#  6: 'Tomato___Spider_mites_Two-spotted_spider_mite',
#  7: 'Tomato___Early_blight',
#  8: 'Tomato___Target_Spot',
#  9: 'Tomato___Tomato_Yellow_Leaf_Curl_Virus'}

# %%
# import the necessary packages
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import numpy as np
import argparse
#import imutils
import pickle
import cv2
import os
import matplotlib.pyplot as plt


# image_path = "sample.jpg"
image_path = "0dc24e61-c636-49e4-9a3d-3aa9a0efb429___GHLB2ES Leaf 69.JPG"
# model_path = "plant_disease.model"
# binarizer_path = "plant_disease.pickle"

# load the image
image = cv2.imread(image_path)
output = image.copy()
 
# pre-process the image for classification
image = cv2.resize(image, (100, 100))
image = image.astype("float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# load the trained convolutional neural network and the label
# binarizer
# print("[INFO] loading network...")
# model = load_model(model_path)
# lb = pickle.loads(open(binarizer_path, "rb").read())

# classify the input image
print("[INFO] classifying image...")
proba = model.predict(image)[0]
idx = np.argmax(proba)
# label = lb.classes_[idx]
val = np.max(proba) * 100
#print(val)
val = "%.3f" % val
cv2.putText(output, label_dictionary[idx], (10, 25),  cv2.FONT_HERSHEY_SIMPLEX,
	0.7, (0, 255, 0), 2)
cv2.putText(output, val + " %", (10, 55),  cv2.FONT_HERSHEY_SIMPLEX,
	0.7, (255, 0, 0), 2)


# show the output image
print("[INFO] class followed by probability...")
plt.imshow(output)
# Out:
# [INFO] classifying image...
# [INFO] class followed by probability...

# %%
outlier_analysis = True
